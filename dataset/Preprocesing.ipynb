# %%
import pandas as pd

# %%
df_input = pd.read_csv('./inputs.csv')
df_outputs = pd.read_csv('./labels.csv')

# %%
df = pd.merge(df_input, df_outputs, on='PatientID', how='inner')

# %%
def preprocess(df):
    # Which columns to keep
    columns_to_keep = [
        'PatientID',
        'Sex',
        'HIVTesting',
        'ECigaretteUsage',
        'DifficultyConcentrating',
        'HadAsthma',
        'HadDepressiveDisorder',
        'CovidPos',
        'FluVaxLast12',
        'RaceEthnicityCategory',
        'HadDiabetes',
        'DifficultyDressingBathing',
        'ChestScan',
        'HadCOPD',
        'BlindOrVisionDifficulty',
        'HighRiskLastYear',
        'HadAngina',
        'PneumoVaxEver',
        'HadSkinCancer',
        'HadArthritis',
        'DeafOrHardOfHearing',
        'AlcoholDrinkers',
        'HadKidneyDisease',
        'TetanusLast10Tdap',
        'SmokerStatus',
        'HeightInMeters',
        'BMI',
        'HadHeartAttack'
    ]
    df = df[columns_to_keep]

    # Turn to bool
    columns_to_transform = [
        'DifficultyConcentrating',
        'HadAsthma',
        'HadDepressiveDisorder',
        'CovidPos',
        'FluVaxLast12',
        'DifficultyDressingBathing',
        'ChestScan',
        'HadCOPD',
        'BlindOrVisionDifficulty',
        'HighRiskLastYear',
        'HadAngina',
        'PneumoVaxEver',
        'HadSkinCancer',
        'HadArthritis',
        'DeafOrHardOfHearing',
        'AlcoholDrinkers',
        'HadKidneyDisease',
        'HadHeartAttack'
    ]
    df[columns_to_transform] = df[columns_to_transform].astype(bool)

    # Rounding
    df['BMI'] = df['BMI'].round(2)

    return df

# %%
preprocess(df).head()
# Out:
# /state/partition1/job-54236473/ipykernel_4057353/1395988784.py:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[columns_to_transform] = df[columns_to_transform].astype(bool)
# /state/partition1/job-54236473/ipykernel_4057353/1395988784.py:59: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['BMI'] = df['BMI'].round(2)
#    PatientID     Sex  HIVTesting                            ECigaretteUsage  \
# 0          1  Female           0  Never used e-cigarettes in my entire life
# 1          2  Female           0  Never used e-cigarettes in my entire life
# 2          3    Male           0  Never used e-cigarettes in my entire life
# 3          4    Male           0  Never used e-cigarettes in my entire life
# 4          8  Female           0  Never used e-cigarettes in my entire life
#
#    DifficultyConcentrating  HadAsthma  HadDepressiveDisorder  CovidPos  \
# 0                    False       True                  False      True
# 1                    False      False                  False     False
# 2                    False      False                  False     False
# 3                    False      False                  False     False
# 4                     True      False                   True     False
#
#    FluVaxLast12     RaceEthnicityCategory  ... HadSkinCancer  HadArthritis  \
# 0         False  White only, Non-Hispanic  ...          True          True
# 1          True  White only, Non-Hispanic  ...         False          True
# 2         False  White only, Non-Hispanic  ...         False         False
# 3          True  White only, Non-Hispanic  ...         False          True
# 4         False  Black only, Non-Hispanic  ...         False          True
#
#    DeafOrHardOfHearing  AlcoholDrinkers  HadKidneyDisease  \
# 0                False            False             False
# 1                False            False             False
# 2                False             True             False
# 3                False            False             False
# 4                 True            False             False
#
#                                    TetanusLast10Tdap   SmokerStatus  \
# 0  No, did not receive any tetanus shot in the pa...  Former smoker
# 1                                 Yes, received Tdap  Former smoker
# 2  Yes, received tetanus shot but not sure what type   Never smoked
# 3  Yes, received tetanus shot but not sure what type  Former smoker
# 4  No, did not receive any tetanus shot in the pa...   Never smoked
#
#    HeightInMeters    BMI  HadHeartAttack
# 0            1.63  32.10           False
# 1            1.60  27.99           False
# 2            1.78  22.53           False
# 3            1.78  30.13           False
# 4            1.70  30.23           False
#
# [5 rows x 28 columns]

# %%
output_path = 'processed_inputs.csv'
df.to_csv(output_path, index=False)

output_path
# Out:
# 'processed_inputs.csv'
