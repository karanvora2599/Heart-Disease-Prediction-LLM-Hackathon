# %%
import pandas as pd
import numpy as np

# %%
# Path to the dataset
data_path = "dataset/processed_inputs.csv"  # Update path as needed

# Load the dataset
df = pd.read_csv(data_path)

# Display the first few rows
print("Dataset Preview:")
df
# Out:
# Dataset Preview:
#         PatientID        State     Sex GeneralHealth   AgeCategory  \
# 0               1      Alabama  Female          Fair  Age 75 to 79
# 1               2      Alabama  Female     Very good  Age 65 to 69
# 2               3      Alabama    Male     Excellent  Age 60 to 64
# 3               4      Alabama    Male     Very good  Age 70 to 74
# 4               8       Alaska  Female          Fair  Age 60 to 64
# ...           ...          ...     ...           ...           ...
# 190152     237624  Puerto Rico  Female          Good  Age 55 to 59
# 190153     237625  Puerto Rico  Female          Poor  Age 70 to 74
# 190154     237626  Puerto Rico  Female          Good  Age 60 to 64
# 190155     237628  Puerto Rico    Male          Fair  Age 45 to 49
# 190156     237630  Puerto Rico  Female          Good  Age 30 to 34
#
#         HeightInMeters  WeightInKilograms        BMI  HadAngina  HadStroke  \
# ...

# %%
import pandas as pd

# Reload the dataset
file_path = 'dataset/processed_inputs.csv'
df = pd.read_csv(file_path)

# Select 10 random rows from the dataframe
random_entities = df.sample(n=10, random_state=42)

# Save the selected entities to a new CSV file
output_path = 'dataset/test.csv'
random_entities.to_csv(output_path, index=False)

output_path
# Out:
# 'dataset/test.csv'
